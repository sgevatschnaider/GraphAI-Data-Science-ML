# %% [markdown]
# <a href="https://colab.research.google.com/github/sgevatschnaider/GraphAI-Data-Science-ML/blob/main/notebooks/Cuestionario_Clase_Tercera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

html_content = r"""
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Preguntas y Respuestas - BIG DATA: Clase Tercera: Grafos, Introducción, Teoría y Práctica</title>
  <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
  <style>
    body {
      font-family: 'Roboto', Arial, sans-serif;
      background-color: #f9f9f9;
      color: #333;
      padding: 20px;
    }
    .container {
      max-width: 900px;
      margin: 0 auto;
    }
    h1 {
      text-align: center;
      margin-bottom: 20px;
    }
    .qa {
      margin-bottom: 20px;
      padding: 15px;
      border: 1px solid #ccc;
      border-radius: 5px;
      background-color: #fff;
    }
    .qa h3 {
      margin-top: 0;
    }
  </style>
</head>
<body>
  <div class="container">
    <h1>Preguntas y Respuestas - BIG DATA: Clase Tercera: Grafos, Introducción, Teoría y Práctica</h1>

    <div class="qa">
      <h3>1. ¿Qué es un grafo en teoría de grafos?</h3>
      <p><strong>Respuesta:</strong> Un grafo es una estructura matemática compuesta por nodos (también llamados vértices) y aristas (o enlaces) que conectan pares de nodos. Puede ser dirigido o no dirigido, y se utiliza para modelar relaciones entre entidades, como redes sociales, rutas de transporte o conexiones en telecomunicaciones.</p>
    </div>

    <div class="qa">
      <h3>2. ¿Qué diferencia hay entre un grafo dirigido y uno no dirigido?</h3>
      <p><strong>Respuesta:</strong> En un grafo dirigido, las aristas tienen una dirección, es decir, van de un nodo origen a un nodo destino. En un grafo no dirigido, las aristas son bidireccionales, representando relaciones simétricas entre los nodos.</p>
    </div>

    <div class="qa">
      <h3>3. ¿Qué representa el Teorema del Apretón de Manos?</h3>
      <p><strong>Respuesta:</strong> Este teorema establece que en cualquier grafo no dirigido, la suma de los grados de todos los nodos es igual al doble del número de aristas: <br><code>∑(v ∈ V) deg(v) = 2E</code>. Esto es útil para verificar la coherencia de datos en estructuras de red.</p>
    </div>

    <div class="qa">
      <h3>4. ¿Qué tipos de grados existen en un grafo dirigido?</h3>
      <p><strong>Respuesta:</strong> Existen dos tipos:
        <ul>
          <li><strong>Grado de entrada (in-degree):</strong> número de aristas que llegan a un nodo.</li>
          <li><strong>Grado de salida (out-degree):</strong> número de aristas que salen de un nodo.</li>
        </ul>
      </p>
    </div>

    <div class="qa">
      <h3>5. ¿Por qué no se pueden usar listas como nodos en NetworkX?</h3>
      <p><strong>Respuesta:</strong> Porque las listas son mutables y no hashables, lo que impide que puedan ser usadas como claves en diccionarios o nodos en grafos. NetworkX requiere nodos que sean objetos inmutables y hashables como tuplas, enteros o strings.</p>
    </div>

    <div class="qa">
      <h3>6. ¿Qué es NetworkX y para qué se utiliza?</h3>
      <p><strong>Respuesta:</strong> Es una biblioteca de Python para crear, manipular y estudiar la estructura, dinámica y funciones de grafos complejos. Se usa ampliamente en análisis de datos, inteligencia artificial, bioinformática, etc.</p>
    </div>

    <div class="qa">
      <h3>7. ¿Qué métodos de creación de grafos ofrece NetworkX?</h3>
      <p><strong>Respuesta:</strong> Algunos métodos incluyen:
        <ul>
          <li><code>nx.Graph()</code> para grafos no dirigidos</li>
          <li><code>nx.DiGraph()</code> para grafos dirigidos</li>
          <li><code>nx.MultiGraph()</code> para múltiples aristas no dirigidas</li>
          <li><code>nx.complete_graph(n)</code> para grafos completos con n nodos</li>
        </ul>
      </p>
    </div>

    <div class="qa">
      <h3>8. ¿Cómo se añaden nodos y aristas en NetworkX?</h3>
      <p><strong>Respuesta:</strong> Se pueden añadir de las siguientes formas:
        <ul>
          <li><code>G.add_node(n)</code> para agregar un nodo</li>
          <li><code>G.add_edge(u, v)</code> para agregar una arista entre <code>u</code> y <code>v</code></li>
          <li><code>G.add_nodes_from([...])</code> o <code>G.add_edges_from([...])</code> para agregar múltiples nodos o aristas</li>
        </ul>
      </p>
    </div>

    <div class="qa">
      <h3>9. ¿Qué es un grafo de cuadrícula o lattice?</h3>
      <p><strong>Respuesta:</strong> Es un tipo de grafo donde los nodos están organizados en una estructura en forma de malla, conectados con sus vecinos inmediatos. Se usa en problemas espaciales, simulaciones y procesamiento de imágenes.</p>
    </div>

    <div class="qa">
      <h3>10. ¿Cuál es la fórmula para calcular el número de aristas en un grafo de malla m × n?</h3>
      <p><strong>Respuesta:</strong> La fórmula es: <br><code>|E| = (m-1) * n + m * (n-1)</code>. Esto se debe a que cada nodo se conecta con su vecino derecho y su vecino inferior.</p>
    </div>

    <div class="qa">
      <h3>11. ¿Qué es la centralidad de grado y cómo se calcula?</h3>
      <p><strong>Respuesta:</strong> Es una medida de cuán conectado está un nodo. Se calcula como: <br><code>C(v) = deg(v) / (n - 1)</code>, donde <code>deg(v)</code> es el grado del nodo y <code>n</code> es el número total de nodos en el grafo.</p>
    </div>

    <div class="qa">
      <h3>12. ¿Qué errores se pueden detectar con el teorema del apretón de manos?</h3>
      <p><strong>Respuesta:</strong> Se pueden detectar inconsistencias en los datos. Por ejemplo, si la suma de los grados no es par, hay un error en el número de conexiones registrado.</p>
    </div>

    <div class="qa">
      <h3>13. ¿Qué significa que un nodo sea ‘hashable’?</h3>
      <p><strong>Respuesta:</strong> Significa que puede convertirse en un valor hash (mediante la función <code>hash()</code>), lo cual es necesario para usarlo como clave en diccionarios o nodos en NetworkX. Solo los objetos inmutables, como enteros, strings y tuplas, son hashables.</p>
    </div>

    <div class="qa">
      <h3>14. ¿Qué sucede si un nodo tiene un grado impar?</h3>
      <p><strong>Respuesta:</strong> En un grafo no dirigido, siempre debe haber un número par de nodos con grado impar. Esto se deduce de la suma de los grados siendo par (por el teorema del apretón de manos).</p>
    </div>

    <div class="qa">
      <h3>15. ¿Qué aplicaciones prácticas tiene el uso de grafos en Big Data?</h3>
      <p><strong>Respuesta:</strong> Los grafos permiten modelar y analizar:
        <ul>
          <li>Redes sociales (amigos, seguidores)</li>
          <li>Rutas óptimas (tráfico, vuelos)</li>
          <li>Sistemas de recomendación (productos, películas)</li>
          <li>Detección de comunidades o patrones en grandes volúmenes de datos</li>
        </ul>
      </p>
    </div>

    <div class="qa">
      <h3>16. ¿Qué es un grafo cubo (hypercube graph) y cómo se construye?</h3>
      <p><strong>Respuesta:</strong> Un grafo cubo, también conocido como grafo hipercubo, es un tipo especial de grafo donde los nodos representan todos los vectores binarios de longitud <em>n</em>, es decir, las cadenas de ceros y unos de tamaño <em>n</em>. Dos nodos están conectados si sus cadenas difieren en exactamente un bit. Por ejemplo, el grafo cubo de dimensión 3 tiene 8 nodos (desde 000 hasta 111) y 12 aristas, formando la estructura de un cubo tridimensional. Este tipo de grafo es simétrico, altamente conexo y se usa en redes paralelas, topologías de comunicación y arquitectura de procesadores.</p>
    </div>

  </div>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Preguntas y Respuestas - BIG DATA: Clase Tercera: Grafos, Introducción, Teoría y Práctica</title>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#   <style>
#     body {
#       font-family: 'Roboto', Arial, sans-serif;
#       background-color: #f9f9f9;
#       color: #333;
#       padding: 20px;
#     }
#     .container {
#       max-width: 900px;
#       margin: 0 auto;
#     }
#     h1 {
#       text-align: center;
#       margin-bottom: 20px;
#     }
#     .qa {
#       margin-bottom: 20px;
#       padding: 15px;
#       border: 1px solid #ccc;
#       border-radius: 5px;
#       background-color: #fff;
#     }
#     .qa h3 {
#       margin-top: 0;
#     }
#   </style>
# </head>
# <body>
#   <div class="container">
# ...
