# %% [markdown]
# <a href="https://colab.research.google.com/github/sgevatschnaider/GraphAI-Data-Science-ML/blob/main/notebooks/Clase_II_La_Computaci%C3%B3n_en_el_Borde_y_su_Aplicaci%C3%B3n_en_IoT_Drones_Inteligentes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

html_content = r"""
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Edge Computing en Drones</title>
  <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
  <style>
    /* Contenedor centralizado */
    .container {
      max-width: 900px;
      margin: 0 auto;
      padding: 20px;
    }
    body {
      font-family: 'Roboto', Arial, sans-serif;
      line-height: 1.8;
      background-color: #f9f9f9;
      color: #333;
      padding: 20px;
      transition: background-color 0.3s, color 0.3s;
    }
    /* Modo oscuro */
    body.dark-mode {
      background-color: #2c3e50;
      color: #ecf0f1;
    }
    h1 {
      text-align: center;
      font-size: 2.5em;
      margin-bottom: 5px;
      color: #2c3e50;
    }
    body.dark-mode h1 {
      color: #ecf0f1;
    }
    h2 {
      color: #2980b9;
      font-size: 1.8em;
      margin-top: 30px;
    }
    body.dark-mode h2 {
      color: #9ad3de;
    }
    h3 {
      margin-top: 10px;
      font-size: 1.2em;
      text-align: center;
      color: #555;
    }
    body.dark-mode h3 {
      color: #bdc3c7;
    }
    p {
      font-size: 1.2em;
      margin-bottom: 15px;
    }
    ul, ol {
      margin-left: 30px;
      margin-bottom: 20px;
    }
    li {
      margin-bottom: 10px;
      font-size: 1.1em;
    }
    hr {
      border: none;
      border-top: 1px solid #ccc;
      margin: 20px 0;
    }
    /* Botón para cambiar tema */
    .theme-toggle {
      background-color: #3498db;
      color: white;
      border: none;
      padding: 8px 12px;
      border-radius: 4px;
      cursor: pointer;
      margin-bottom: 20px;
      display: block;
      margin-left: auto;
      margin-right: auto;
      transition: background-color 0.3s;
    }
    .theme-toggle:hover {
      background-color: #2980b9;
    }
    @media (max-width: 600px) {
      body { padding: 10px; }
      p, ul, ol { padding: 10px; }
      li { font-size: 1em; }
    }
    /* Resalta palabras clave */
    .keyword {
      color: #e74c3c;
      font-weight: bold;
    }
    /* Estilos de tabla */
    table {
      border-collapse: collapse;
      width: 100%;
      margin-bottom: 15px;
    }
    table, th, td {
      border: 1px solid #2c3e50;
      padding: 8px;
      text-align: left;
    }
    body.dark-mode table, body.dark-mode th, body.dark-mode td {
      border: 1px solid #ecf0f1;
    }
    th {
      background-color: #ecf0f1;
    }
    body.dark-mode th {
      background-color: #34495e;
    }
  </style>
</head>
<body>
  <div class="container">
    <button class="theme-toggle" onclick="toggleTheme()">Cambiar Tema</button>
    <h1>Edge Computing en Drones</h1>
    <h3>Material elaborado por Sergio Gevatschnaider</h3>

    <h2>Introducción</h2>
    <p>
      El desarrollo tecnológico ha llevado a la aparición de <span class="keyword">Edge Computing</span>, un paradigma que permite el procesamiento de datos en el mismo dispositivo o cerca de su origen, en lugar de depender de servidores remotos. En el ámbito de los drones, esta tecnología es crucial para mejorar la toma de decisiones en tiempo real, optimizar la eficiencia operativa y permitir aplicaciones en entornos con conectividad limitada.
    </p>
    <p>
      Este documento explora el impacto de Edge Computing en drones, destacando sus beneficios, aplicaciones y el futuro de esta tecnología en diferentes industrias.
    </p>

    <hr>

    <h2>Objetivo Educativo</h2>
    <p>
      El propósito de este documento es que los estudiantes y profesionales:
    </p>
    <ul>
      <li><span class="keyword">Comprendan</span> el concepto de Edge Computing y su importancia en el procesamiento de datos en tiempo real.</li>
      <li><span class="keyword">Analicen</span> cómo esta tecnología mejora el rendimiento y la autonomía de los drones.</li>
      <li><span class="keyword">Identifiquen</span> aplicaciones reales de drones con Edge Computing en sectores como seguridad, agricultura, logística e inteligencia artificial.</li>
      <li><span class="keyword">Exploren</span> herramientas y hardware utilizados en Edge Computing para drones.</li>
    </ul>

    <hr>

    <h2>Índice</h2>
    <ol>
      <li><strong>Introducción</strong></li>
      <li><strong>Edge Computing: Concepto y Características</strong></li>
      <li>
        <strong>Ventajas del Edge Computing en Drones</strong>
        <ul>
          <li>Procesamiento en tiempo real</li>
          <li>Reducción de latencia</li>
          <li>Operación en entornos sin conexión</li>
          <li>Optimización del ancho de banda</li>
        </ul>
      </li>
      <li>
        <strong>Aplicaciones de Edge Computing en Drones</strong>
        <ul>
          <li>Seguridad y vigilancia</li>
          <li>Agricultura de precisión</li>
          <li>Rescate y emergencias</li>
          <li>Industria y logística</li>
          <li>Carreras y FPV (First Person View)</li>
        </ul>
      </li>
      <li>
        <strong>Hardware y Software para Edge Computing en Drones</strong>
        <ul>
          <li>Procesadores y chips especializados</li>
          <li>Algoritmos de inteligencia artificial</li>
          <li>Plataformas de desarrollo</li>
        </ul>
      </li>
      <li><strong>Desafíos y Futuro de Edge Computing en Drones</strong></li>
      <li>
        <strong>Recursos Adicionales</strong>
        <ul>
          <li><span class="keyword">Videos educativos</span>:
            <ul>
              <li>Edge Computing Drones: The Future of UAVs and Efficient Data Processing</li>
              <li>How AI and Edge Computing Make Drones Smarter</li>
            </ul>
          </li>
          <li><span class="keyword">Lecturas recomendadas</span>:
            <ul>
              <li>Artículo de IEEE sobre Edge Computing en UAVs</li>
              <li>Blog de NVIDIA sobre IA y Edge Computing en drones</li>
            </ul>
          </li>
          <li><span class="keyword">Herramientas y Hardware</span>:
            <ul>
              <li>NVIDIA Jetson Xavier NX: Para procesamientos avanzados en el borde.</li>
              <li>Raspberry Pi 4: Alternativa económica para procesamiento en drones.</li>
              <li>Intel Movidius Neural Compute Stick: Para aplicaciones de visión artificial en el borde.</li>
            </ul>
          </li>
        </ul>
      </li>
    </ol>

    <hr>

    <h2>Recursos Adicionales</h2>
    <p>
      Para reforzar el aprendizaje se recomienda revisar los siguientes recursos:
    </p>
    <p>
      <strong>Videos Educativos:</strong><br>
      <em>Edge Computing Drones: The Future of UAVs and Efficient Data Processing</em><br>
      <em>How AI and Edge Computing Make Drones Smarter</em>
    </p>
    <p>
      <strong>Lecturas Recomendadas:</strong><br>
      Artículo de IEEE sobre Edge Computing en UAVs<br>
      Blog de NVIDIA sobre IA y Edge Computing en drones
    </p>
    <p>
      <strong>Herramientas y Hardware:</strong><br>
      NVIDIA Jetson Xavier NX, Raspberry Pi 4, Intel Movidius Neural Compute Stick.
    </p>

  </div>
  <script>
    function toggleTheme() {
      document.body.classList.toggle("dark-mode");
    }
  </script>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Edge Computing en Drones</title>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#   <style>
#     /* Contenedor centralizado */
#     .container {
#       max-width: 900px;
#       margin: 0 auto;
#       padding: 20px;
#     }
#     body {
#       font-family: 'Roboto', Arial, sans-serif;
#       line-height: 1.8;
#       background-color: #f9f9f9;
#       color: #333;
#       padding: 20px;
#       transition: background-color 0.3s, color 0.3s;
#     }
#     /* Modo oscuro */
#     body.dark-mode {
#       background-color: #2c3e50;
#       color: #ecf0f1;
#     }
#     h1 {
#       text-align: center;
#       font-size: 2.5em;
#       margin-bottom: 5px;
#       color: #2c3e50;
#     }
#     body.dark-mode h1 {
#       color: #ecf0f1;
#     }
#     h2 {
# ...

# %%
from IPython.display import display, HTML

html_content = r"""
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Computación en el Borde y su Relación con el IoT</title>
  <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
  <style>
    /* Contenedor centralizado */
    .container {
      max-width: 900px;
      margin: 0 auto;
      padding: 20px;
    }
    body {
      font-family: 'Roboto', Arial, sans-serif;
      line-height: 1.8;
      background-color: #f9f9f9;
      color: #333;
      padding: 20px;
      transition: background-color 0.3s, color 0.3s;
    }
    /* Modo oscuro */
    body.dark-mode {
      background-color: #2c3e50;
      color: #ecf0f1;
    }
    h1 {
      text-align: center;
      font-size: 2.5em;
      margin-bottom: 20px;
      color: #2c3e50;
    }
    body.dark-mode h1 {
      color: #ecf0f1;
    }
    h2 {
      color: #2980b9;
      font-size: 1.8em;
      margin-top: 30px;
    }
    body.dark-mode h2 {
      color: #9ad3de;
    }
    p {
      font-size: 1.2em;
      margin-bottom: 15px;
    }
    ul {
      margin-left: 30px;
      margin-bottom: 20px;
    }
    li {
      margin-bottom: 10px;
      font-size: 1.1em;
    }
    hr {
      border: none;
      border-top: 1px solid #ccc;
      margin: 20px 0;
    }
    /* Botón para cambiar tema */
    .theme-toggle {
      background-color: #3498db;
      color: white;
      border: none;
      padding: 8px 12px;
      border-radius: 4px;
      cursor: pointer;
      margin-bottom: 20px;
      display: block;
      margin-left: auto;
      margin-right: auto;
      transition: background-color 0.3s;
    }
    .theme-toggle:hover {
      background-color: #2980b9;
    }
    @media (max-width: 600px) {
      body { padding: 10px; }
      p, ul { padding: 10px; }
      li { font-size: 1em; }
    }
    /* Resalta palabras clave */
    .keyword {
      color: #e74c3c;
      font-weight: bold;
    }
  </style>
</head>
<body>
  <div class="container">
    <button class="theme-toggle" onclick="toggleTheme()">Cambiar Tema</button>
    <h1>Computación en el Borde (Edge Computing) y su Relación con el IoT</h1>
    <p>
      La imagen ilustra el concepto de <strong>Edge Computing</strong>, una tecnología clave para optimizar el procesamiento de datos en dispositivos del <strong>Internet de las Cosas (IoT)</strong>.
    </p>
    <p>
      En lugar de enviar toda la información generada por sensores y dispositivos inteligentes directamente a la <strong>nube</strong> o a un <strong>centro de datos</strong>, el procesamiento ocurre en el <strong>borde (edge)</strong> de la red. Esto permite:
    </p>
    <ul>
      <li><strong>Procesamiento de datos en tiempo real:</strong> Los dispositivos pueden realizar análisis básicos sin depender de una conexión constante con la nube.</li>
      <li><strong>Reducción de latencia:</strong> Al evitar el envío continuo de datos a servidores remotos, las decisiones se toman más rápido.</li>
      <li><strong>Eficiencia en el uso del ancho de banda:</strong> Solo se transmiten datos relevantes o procesados, reduciendo la carga en la red.</li>
      <li><strong>Interacción máquina a máquina (M2M):</strong> Los dispositivos pueden comunicarse entre sí sin necesidad de intermediarios en la nube.</li>
    </ul>
    <p>
      Este enfoque es esencial para aplicaciones críticas como <strong>automóviles conectados, fábricas inteligentes, energías renovables y redes eléctricas inteligentes</strong>.
    </p>
    <p>
      En resumen, <strong>Edge Computing</strong> mejora la eficiencia y confiabilidad de los sistemas IoT, permitiendo una mayor autonomía y optimización del procesamiento de datos.
    </p>
  </div>
  <script>
    function toggleTheme() {
      document.body.classList.toggle("dark-mode");
    }
  </script>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Computación en el Borde y su Relación con el IoT</title>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#   <style>
#     /* Contenedor centralizado */
#     .container {
#       max-width: 900px;
#       margin: 0 auto;
#       padding: 20px;
#     }
#     body {
#       font-family: 'Roboto', Arial, sans-serif;
#       line-height: 1.8;
#       background-color: #f9f9f9;
#       color: #333;
#       padding: 20px;
#       transition: background-color 0.3s, color 0.3s;
#     }
#     /* Modo oscuro */
#     body.dark-mode {
#       background-color: #2c3e50;
#       color: #ecf0f1;
#     }
#     h1 {
#       text-align: center;
#       font-size: 2.5em;
#       margin-bottom: 20px;
#       color: #2c3e50;
#     }
#     body.dark-mode h1 {
#       color: #ecf0f1;
# ...

# %%
from IPython.display import display, HTML

html_content = r"""
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Computación en el Borde y su Relación con el IoT</title>
  <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
  <style>
    /* Contenedor centralizado */
    .container {
      max-width: 900px;
      margin: 0 auto;
      padding: 20px;
    }
    body {
      font-family: 'Roboto', Arial, sans-serif;
      line-height: 1.8;
      background-color: #f9f9f9;
      color: #333;
      padding: 20px;
      transition: background-color 0.3s, color 0.3s;
    }
    /* Modo oscuro */
    body.dark-mode {
      background-color: #2c3e50;
      color: #ecf0f1;
    }
    h1 {
      text-align: center;
      font-size: 2.5em;
      margin-bottom: 20px;
      color: #2c3e50;
    }
    body.dark-mode h1 {
      color: #ecf0f1;
    }
    h2 {
      color: #2980b9;
      font-size: 1.8em;
      margin-top: 30px;
    }
    body.dark-mode h2 {
      color: #9ad3de;
    }
    p {
      font-size: 1.2em;
      margin-bottom: 15px;
    }
    ul {
      margin-left: 30px;
      margin-bottom: 20px;
    }
    li {
      margin-bottom: 10px;
      font-size: 1.1em;
    }
    hr {
      border: none;
      border-top: 1px solid #ccc;
      margin: 20px 0;
    }
    /* Botón para cambiar tema */
    .theme-toggle {
      background-color: #3498db;
      color: white;
      border: none;
      padding: 8px 12px;
      border-radius: 4px;
      cursor: pointer;
      margin-bottom: 20px;
      display: block;
      margin-left: auto;
      margin-right: auto;
      transition: background-color 0.3s;
    }
    .theme-toggle:hover {
      background-color: #2980b9;
    }
    /* Botón de enlace para el video */
    .video-button {
      background-color: #e67e22;
      color: white;
      border: none;
      padding: 10px 16px;
      border-radius: 4px;
      text-decoration: none;
      font-size: 1.1em;
      display: inline-block;
      margin-top: 20px;
      transition: background-color 0.3s;
    }
    .video-button:hover {
      background-color: #d35400;
    }
    @media (max-width: 600px) {
      body { padding: 10px; }
      p, ul { padding: 10px; }
      li { font-size: 1em; }
    }
    /* Resalta palabras clave */
    .keyword {
      color: #e74c3c;
      font-weight: bold;
    }
  </style>
</head>
<body>
  <div class="container">
    <button class="theme-toggle" onclick="toggleTheme()">Cambiar Tema</button>
    <h1>Computación en el Borde y su Relación con el IoT</h1>
    <p>
      La imagen ilustra el concepto de <strong>Edge Computing</strong>, una tecnología clave para optimizar el procesamiento de datos en dispositivos del <strong>Internet de las Cosas (IoT)</strong>.
    </p>
    <p>
      En lugar de enviar toda la información generada por sensores y dispositivos inteligentes directamente a la <strong>nube</strong> o a un <strong>centro de datos</strong>, el procesamiento ocurre en el <strong>borde (edge)</strong> de la red. Esto permite:
    </p>
    <ul>
      <li><strong>Procesamiento de datos en tiempo real:</strong> Los dispositivos pueden realizar análisis básicos sin depender de una conexión constante con la nube.</li>
      <li><strong>Reducción de latencia:</strong> Al evitar el envío continuo de datos a servidores remotos, las decisiones se toman más rápido.</li>
      <li><strong>Eficiencia en el uso del ancho de banda:</strong> Solo se transmiten datos relevantes o procesados, reduciendo la carga en la red.</li>
      <li><strong>Interacción máquina a máquina (M2M):</strong> Los dispositivos pueden comunicarse entre sí sin necesidad de intermediarios en la nube.</li>
    </ul>
    <p>
      Este enfoque es esencial para aplicaciones críticas como <strong>automóviles conectados, fábricas inteligentes, energías renovables y redes eléctricas inteligentes</strong>.
    </p>
    <p>
      En resumen, <strong>Edge Computing</strong> mejora la eficiencia y confiabilidad de los sistemas IoT, permitiendo una mayor autonomía y optimización del procesamiento de datos.
    </p>
    <!-- Botón de video -->
    <a class="video-button" href="https://www.youtube.com/watch?v=MBUabimpai0" target="_blank">Ver Video</a>
  </div>
  <script>
    function toggleTheme() {
      document.body.classList.toggle("dark-mode");
    }
  </script>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Computación en el Borde y su Relación con el IoT</title>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#   <style>
#     /* Contenedor centralizado */
#     .container {
#       max-width: 900px;
#       margin: 0 auto;
#       padding: 20px;
#     }
#     body {
#       font-family: 'Roboto', Arial, sans-serif;
#       line-height: 1.8;
#       background-color: #f9f9f9;
#       color: #333;
#       padding: 20px;
#       transition: background-color 0.3s, color 0.3s;
#     }
#     /* Modo oscuro */
#     body.dark-mode {
#       background-color: #2c3e50;
#       color: #ecf0f1;
#     }
#     h1 {
#       text-align: center;
#       font-size: 2.5em;
#       margin-bottom: 20px;
#       color: #2c3e50;
#     }
#     body.dark-mode h1 {
#       color: #ecf0f1;
# ...

# %%
from IPython.display import display, HTML

html_content = r"""
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>MLPerf Scenarios y su Relación con Edge Computing e IoT</title>
  <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
  <style>
    /* Contenedor centralizado */
    .container {
      max-width: 900px;
      margin: 0 auto;
      padding: 20px;
    }
    body {
      font-family: 'Roboto', Arial, sans-serif;
      line-height: 1.8;
      background-color: #f9f9f9;
      color: #333;
      padding: 20px;
      transition: background-color 0.3s, color 0.3s;
    }
    /* Modo oscuro */
    body.dark-mode {
      background-color: #2c3e50;
      color: #ecf0f1;
    }
    h1 {
      text-align: center;
      font-size: 2.5em;
      margin-bottom: 20px;
      color: #2c3e50;
    }
    body.dark-mode h1 {
      color: #ecf0f1;
    }
    h2 {
      color: #2980b9;
      font-size: 1.8em;
      margin-top: 30px;
    }
    body.dark-mode h2 {
      color: #9ad3de;
    }
    h3 {
      margin-top: 25px;
      font-size: 1.5em;
    }
    p {
      font-size: 1.2em;
      margin-bottom: 15px;
    }
    ul, ol {
      margin-left: 30px;
      margin-bottom: 20px;
    }
    li {
      margin-bottom: 10px;
      font-size: 1.1em;
    }
    hr {
      border: none;
      border-top: 1px solid #ccc;
      margin: 20px 0;
    }
    /* Botón para cambiar tema */
    .theme-toggle {
      background-color: #3498db;
      color: white;
      border: none;
      padding: 8px 12px;
      border-radius: 4px;
      cursor: pointer;
      margin-bottom: 20px;
      display: block;
      margin-left: auto;
      margin-right: auto;
      transition: background-color 0.3s;
    }
    .theme-toggle:hover {
      background-color: #2980b9;
    }
    @media (max-width: 600px) {
      body { padding: 10px; }
      p, ul, ol { padding: 10px; }
      li { font-size: 1em; }
    }
    /* Resalta palabras clave */
    .keyword {
      color: #e74c3c;
      font-weight: bold;
    }
  </style>
</head>
<body>
  <div class="container">
    <button class="theme-toggle" onclick="toggleTheme()">Cambiar Tema</button>
    <h1>MLPerf Scenarios y su Relación con Edge Computing e IoT</h1>
    <p>
      La imagen muestra diferentes <strong>escenarios de inferencia en Machine Learning (MLPerf)</strong>, que evalúan el rendimiento de modelos de inteligencia artificial en distintos entornos. Esto se relaciona con <strong>Edge Computing</strong> e <strong>IoT</strong> porque los dispositivos inteligentes, como los sensores o cámaras en la red, a menudo deben ejecutar modelos de IA para tomar decisiones en tiempo real.
    </p>
    <hr>
    <h2>Relación con Edge Computing e IoT</h2>
    <p>
      En sistemas de <strong>Edge Computing</strong>, los dispositivos procesan datos localmente en lugar de enviarlos a la nube. Dependiendo del caso de uso, el procesamiento de inferencia puede ajustarse a diferentes escenarios, como se muestra a continuación:
    </p>
    <ol>
      <li>
        <strong>OFFLINE</strong><br>
        - Se procesan grandes lotes de datos en un solo paso.<br>
        - <strong>Ejemplo en Edge Computing:</strong> Un dron captura imágenes y, al aterrizar, procesa todos los datos de manera local antes de enviarlos a la nube.<br>
        - <strong>Ventaja:</strong> Alta eficiencia en throughput.<br>
        - <strong>Desventaja:</strong> No es útil para tareas en tiempo real.
      </li>
      <li>
        <strong>SINGLE STREAM</strong><br>
        - Procesa una muestra a la vez y mide la latencia de cada inferencia.<br>
        - <strong>Ejemplo en Edge Computing:</strong> Un sensor de IoT en una fábrica analiza la temperatura en tiempo real y envía alertas si detecta valores peligrosos.<br>
        - <strong>Ventaja:</strong> Respuesta inmediata.<br>
        - <strong>Desventaja:</strong> Puede ser lento para procesar grandes volúmenes de datos.
      </li>
      <li>
        <strong>SERVER</strong><br>
        - Maneja múltiples consultas de inferencia que llegan de manera aleatoria y las agrupa según un presupuesto de latencia.<br>
        - <strong>Ejemplo en Edge Computing:</strong> Cámaras de seguridad inteligentes en una ciudad que procesan imágenes en servidores locales y responden a eventos sospechosos en tiempo real.<br>
        - <strong>Ventaja:</strong> Optimización del uso de recursos manteniendo baja latencia.<br>
        - <strong>Desventaja:</strong> Mayor consumo de energía y necesidad de hardware más potente.
      </li>
      <li>
        <strong>MULTI STREAM</strong><br>
        - Procesa múltiples muestras en paralelo con un tiempo límite para completar la inferencia.<br>
        - <strong>Ejemplo en Edge Computing:</strong> Un sistema de monitoreo de tráfico que analiza imágenes de varias cámaras al mismo tiempo para ajustar los semáforos en tiempo real.<br>
        - <strong>Ventaja:</strong> Manejo eficiente de múltiples flujos de datos con baja latencia.<br>
        - <strong>Desventaja:</strong> Necesita mayor capacidad de procesamiento en el borde.
      </li>
    </ol>
    <hr>
    <h2>Conclusión</h2>
    <ul>
      <li><strong>Edge Computing</strong> y MLPerf están estrechamente relacionados, ya que los dispositivos IoT necesitan ejecutar modelos de IA en el borde para responder rápidamente sin depender de la nube.</li>
      <li>El escenario ideal depende del caso de uso: Single Stream para respuestas rápidas; Multi Stream o Server para sistemas con múltiples fuentes de datos; Offline para procesamiento masivo sin urgencia de respuesta inmediata.</li>
      <li>Optimizar el procesamiento de inferencia en el borde permite mejorar la eficiencia, reducir la latencia y minimizar el uso del ancho de banda en redes IoT.</li>
      <li>Este enfoque es clave para ciudades inteligentes, fábricas automatizadas y vehículos autónomos, donde el tiempo de respuesta es crítico.</li>
    </ul>
    <!-- Botón para ver video -->
    <a class="theme-toggle video-button" href="https://www.youtube.com/watch?v=MBUabimpai0" target="_blank" style="text-align:center; display:block; max-width:200px; margin:20px auto;">Ver Video</a>
  </div>
  <script>
    function toggleTheme() {
      document.body.classList.toggle("dark-mode");
    }
  </script>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>MLPerf Scenarios y su Relación con Edge Computing e IoT</title>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#   <style>
#     /* Contenedor centralizado */
#     .container {
#       max-width: 900px;
#       margin: 0 auto;
#       padding: 20px;
#     }
#     body {
#       font-family: 'Roboto', Arial, sans-serif;
#       line-height: 1.8;
#       background-color: #f9f9f9;
#       color: #333;
#       padding: 20px;
#       transition: background-color 0.3s, color 0.3s;
#     }
#     /* Modo oscuro */
#     body.dark-mode {
#       background-color: #2c3e50;
#       color: #ecf0f1;
#     }
#     h1 {
#       text-align: center;
#       font-size: 2.5em;
#       margin-bottom: 20px;
#       color: #2c3e50;
#     }
#     body.dark-mode h1 {
# ...

# %%
from IPython.display import display, HTML

html_content = r"""
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Computación en el Borde y su Relación con el IoT</title>
  <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
  <style>
    /* Contenedor centralizado */
    .container {
      max-width: 900px;
      margin: 0 auto;
      padding: 20px;
    }
    body {
      font-family: 'Roboto', Arial, sans-serif;
      line-height: 1.8;
      background-color: #f9f9f9;
      color: #333;
      padding: 20px;
      transition: background-color 0.3s, color 0.3s;
    }
    /* Modo oscuro */
    body.dark-mode {
      background-color: #2c3e50;
      color: #ecf0f1;
    }
    h1 {
      text-align: center;
      font-size: 2.5em;
      margin-bottom: 20px;
      color: #2c3e50;
    }
    body.dark-mode h1 {
      color: #ecf0f1;
    }
    h2 {
      color: #2980b9;
      font-size: 1.8em;
      margin-top: 30px;
    }
    body.dark-mode h2 {
      color: #9ad3de;
    }
    p {
      font-size: 1.2em;
      margin-bottom: 15px;
    }
    ul {
      margin-left: 30px;
      margin-bottom: 20px;
    }
    li {
      margin-bottom: 10px;
      font-size: 1.1em;
    }
    hr {
      border: none;
      border-top: 1px solid #ccc;
      margin: 20px 0;
    }
    /* Botón para cambiar tema */
    .theme-toggle {
      background-color: #3498db;
      color: white;
      border: none;
      padding: 8px 12px;
      border-radius: 4px;
      cursor: pointer;
      margin-bottom: 20px;
      display: block;
      margin-left: auto;
      margin-right: auto;
      transition: background-color 0.3s;
    }
    .theme-toggle:hover {
      background-color: #2980b9;
    }
    @media (max-width: 600px) {
      body { padding: 10px; }
      p, ul { padding: 10px; }
      li { font-size: 1em; }
    }
    /* Resalta palabras clave */
    .keyword {
      color: #e74c3c;
      font-weight: bold;
    }
    /* Botón de video */
    .video-button {
      background-color: #e67e22;
      color: white;
      border: none;
      padding: 10px 16px;
      border-radius: 4px;
      text-decoration: none;
      font-size: 1.1em;
      display: block;
      text-align: center;
      max-width: 300px;
      margin: 20px auto;
      transition: background-color 0.3s;
    }
    .video-button:hover {
      background-color: #d35400;
    }
  </style>
</head>
<body>
  <div class="container">
    <button class="theme-toggle" onclick="toggleTheme()">Cambiar Tema</button>
    <h1>Computación en el Borde y su Relación con el IoT</h1>
    <p>
      La imagen ilustra el concepto de <strong>Edge Computing</strong>, una tecnología clave para optimizar el procesamiento de datos en dispositivos del <strong>Internet de las Cosas (IoT)</strong>.
    </p>
    <p>
      En lugar de enviar toda la información generada por sensores y dispositivos inteligentes directamente a la <strong>nube</strong> o a un <strong>centro de datos</strong>, el procesamiento ocurre en el <strong>borde (edge)</strong> de la red. Esto permite:
    </p>
    <ul>
      <li><strong>Procesamiento de datos en tiempo real:</strong> Los dispositivos pueden realizar análisis básicos sin depender de una conexión constante con la nube.</li>
      <li><strong>Reducción de latencia:</strong> Al evitar el envío continuo de datos a servidores remotos, las decisiones se toman más rápido.</li>
      <li><strong>Eficiencia en el uso del ancho de banda:</strong> Solo se transmiten datos relevantes o procesados, reduciendo la carga en la red.</li>
      <li><strong>Interacción máquina a máquina (M2M):</strong> Los dispositivos pueden comunicarse entre sí sin necesidad de intermediarios en la nube.</li>
    </ul>
    <p>
      Este enfoque es esencial para aplicaciones críticas como <strong>automóviles conectados, fábricas inteligentes, energías renovables y redes eléctricas inteligentes</strong>. En resumen, <strong>Edge Computing</strong> mejora la eficiencia y confiabilidad de los sistemas IoT, permitiendo una mayor autonomía y optimización del procesamiento de datos.
    </p>
    <h2>Aplicación de Edge Computing en drones</h2>
    <p>
      Para ilustrar la aplicación de <strong>Edge Computing en drones</strong> durante tu clase, te recomiendo el siguiente video. Este recurso visual complementa la información, mostrando cómo los drones equipados con capacidades de Edge Computing pueden procesar datos de manera eficiente y en tiempo real, mejorando su autonomía y reduciendo la dependencia de la nube.
    </p>
    <a class="video-button" href="https://www.youtube.com/watch?v=V3cP272TZnE" target="_blank">
      Edge Computing Drones: The Future of UAVs and Efficient Data Processing
    </a>
  </div>
  <script>
    function toggleTheme() {
      document.body.classList.toggle("dark-mode");
    }
  </script>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Computación en el Borde y su Relación con el IoT</title>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#   <style>
#     /* Contenedor centralizado */
#     .container {
#       max-width: 900px;
#       margin: 0 auto;
#       padding: 20px;
#     }
#     body {
#       font-family: 'Roboto', Arial, sans-serif;
#       line-height: 1.8;
#       background-color: #f9f9f9;
#       color: #333;
#       padding: 20px;
#       transition: background-color 0.3s, color 0.3s;
#     }
#     /* Modo oscuro */
#     body.dark-mode {
#       background-color: #2c3e50;
#       color: #ecf0f1;
#     }
#     h1 {
#       text-align: center;
#       font-size: 2.5em;
#       margin-bottom: 20px;
#       color: #2c3e50;
#     }
#     body.dark-mode h1 {
#       color: #ecf0f1;
# ...

# %%
from IPython.display import display, HTML

html_content = r"""
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Preguntas y Respuestas - Edge Computing e IoT</title>
  <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
  <style>
    body {
      font-family: 'Roboto', Arial, sans-serif;
      background-color: #f9f9f9;
      color: #333;
      padding: 20px;
    }
    .container {
      max-width: 900px;
      margin: 0 auto;
    }
    h1 {
      text-align: center;
      margin-bottom: 20px;
    }
    .qa {
      margin-bottom: 20px;
      padding: 15px;
      border: 1px solid #ccc;
      border-radius: 5px;
      background-color: #fff;
    }
    .qa h3 {
      margin-top: 0;
    }
  </style>
</head>
<body>
  <div class="container">
    <h1>Preguntas y Respuestas - Edge Computing e IoT</h1>

    <div class="qa">
      <h3>1. ¿Qué es Edge Computing?</h3>
      <p><strong>Respuesta:</strong> Edge Computing es un paradigma tecnológico que permite procesar los datos en el mismo dispositivo o en la proximidad de su origen, en lugar de enviarlos a la nube o a servidores remotos.</p>
    </div>

    <div class="qa">
      <h3>2. ¿Cuáles son las principales ventajas de implementar Edge Computing en dispositivos IoT?</h3>
      <p><strong>Respuesta:</strong> Entre sus principales ventajas se encuentran el procesamiento en tiempo real, la reducción de latencia, la optimización del uso del ancho de banda y la facilitación de la interacción máquina a máquina (M2M).</p>
    </div>

    <div class="qa">
      <h3>3. ¿Cómo mejora Edge Computing la eficiencia y confiabilidad de los sistemas IoT?</h3>
      <p><strong>Respuesta:</strong> Al procesar los datos localmente, Edge Computing permite respuestas inmediatas y reduce la dependencia de una conexión constante a la nube, optimizando así el uso de recursos y mejorando la eficiencia global del sistema.</p>
    </div>

    <div class="qa">
      <h3>4. ¿Qué aplicaciones críticas se benefician del uso de Edge Computing?</h3>
      <p><strong>Respuesta:</strong> Aplicaciones como automóviles conectados, fábricas inteligentes, energías renovables y redes eléctricas inteligentes se benefician de Edge Computing, ya que requieren respuestas rápidas y un procesamiento local eficiente.</p>
    </div>

    <div class="qa">
      <h3>5. ¿Cómo se relaciona Edge Computing con los escenarios de inferencia en MLPerf?</h3>
      <p><strong>Respuesta:</strong> Edge Computing permite ejecutar modelos de inteligencia artificial directamente en dispositivos IoT. Esto se traduce en la adaptación de diferentes escenarios de inferencia, como SINGLE STREAM para respuestas inmediatas y MULTI STREAM para procesamiento en paralelo, optimizando el rendimiento y la latencia según las necesidades de la aplicación.</p>
    </div>

  </div>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Preguntas y Respuestas - Edge Computing e IoT</title>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#   <style>
#     body {
#       font-family: 'Roboto', Arial, sans-serif;
#       background-color: #f9f9f9;
#       color: #333;
#       padding: 20px;
#     }
#     .container {
#       max-width: 900px;
#       margin: 0 auto;
#     }
#     h1 {
#       text-align: center;
#       margin-bottom: 20px;
#     }
#     .qa {
#       margin-bottom: 20px;
#       padding: 15px;
#       border: 1px solid #ccc;
#       border-radius: 5px;
#       background-color: #fff;
#     }
#     .qa h3 {
#       margin-top: 0;
#     }
#   </style>
# </head>
# <body>
#   <div class="container">
#     <h1>Preguntas y Respuestas - Edge Computing e IoT</h1>
#
#     <div class="qa">
# ...
